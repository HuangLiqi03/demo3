# %%
# 读取pkl
import pickle
with open('/hard_data/user_dataset/huangliqi_dataset/demo3/demos/ms-poke-cube-semi/ms-poke-cube-semi_trajectories_20.pkl', 'rb') as f:
    data = pickle.load(f)
print(data)

# %%
print(data[0])
